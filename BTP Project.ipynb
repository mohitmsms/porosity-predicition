# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_excel("TOTALDATA REAL.xlsx")

# %%
df.head()
# Out:
#    IMAGE DERIVED DENSITY  BEST CALIPER,AVERAGE DIAMETER  \
# 0                 2.5059                        10.6431
# 1                 2.5460                        10.7011
# 2                 2.5642                        10.7012
# 3                 2.5808                        10.6773
# 4                 2.5632                        10.6162
#
#    IMAGE DERIVED PHOTOELECTRIC FACTOR  BEST THERMAL POROSITY  TOTAL POROSITY  \
# 0                             18.4555                 0.1919          0.1300
# 1                             18.8648                 0.1862          0.1111
# 2                             19.3160                 0.1830          0.1015
# 3                             19.6845                 0.1739          0.0927
# 4                             19.4390                 0.1547          0.1053
#
#    RESISTIVITY OF WATER FILLED FORMATION  \
# 0                                 3.8568
# 1                                 4.9163
# 2                                 5.7882
# 3                                 6.8120
# 4                                 5.4189
#
#    RELATIVE PERMEABILITY TO HYDROCARBON  RELATIVE PERMEABILITY TO WATER  \
# 0                                   0.0                             1.0
# 1                                   0.0                             1.0
# 2                                   0.0                             1.0
# 3                                   0.0                             1.0
# 4                                   0.0                             1.0
#
#    WATER CUT  MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS       .1
# 0        1.0                                             2.7292 NaN  NaN
# 1        1.0                                             2.7379 NaN  NaN
# 2        1.0                                             2.7397 NaN  NaN
# 3        1.0                                             2.7413 NaN  NaN
# 4        1.0                                             2.7459 NaN  NaN

# %%
df.columns
# Out:
# Index(['IMAGE DERIVED DENSITY', 'BEST CALIPER,AVERAGE DIAMETER',
#        'IMAGE DERIVED PHOTOELECTRIC FACTOR', 'BEST THERMAL POROSITY',
#        'TOTAL POROSITY', 'RESISTIVITY OF WATER FILLED FORMATION',
#        'RELATIVE PERMEABILITY TO HYDROCARBON',
#        'RELATIVE PERMEABILITY TO WATER', 'WATER CUT',
#        'MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS', ' ', ' .1'],
#       dtype='object')

# %%
df=df.drop([' ', ' .1','BEST THERMAL POROSITY','IMAGE DERIVED DENSITY'],axis=1)

# %%
df.shape
# Out:
# (4849, 8)

# %%
df.isnull()
# Out:
#       BEST CALIPER,AVERAGE DIAMETER  IMAGE DERIVED PHOTOELECTRIC FACTOR  \
# 0                             False                               False
# 1                             False                               False
# 2                             False                               False
# 3                             False                               False
# 4                             False                               False
# ...                             ...                                 ...
# 4844                          False                               False
# 4845                          False                               False
# 4846                          False                               False
# 4847                          False                               False
# 4848                          False                               False
#
#       TOTAL POROSITY  RESISTIVITY OF WATER FILLED FORMATION  \
# 0              False                                  False
# 1              False                                  False
# 2              False                                  False
# 3              False                                  False
# 4              False                                  False
# ...              ...                                    ...
# 4844           False                                  False
# 4845           False                                  False
# 4846           False                                  False
# 4847           False                                  False
# 4848           False                                  False
#
#       RELATIVE PERMEABILITY TO HYDROCARBON  RELATIVE PERMEABILITY TO WATER  \
# 0                                    False                           False
# 1                                    False                           False
# 2                                    False                           False
# 3                                    False                           False
# 4                                    False                           False
# ...                                    ...                             ...
# 4844                                 False                           False
# 4845                                 False                           False
# 4846                                 False                           False
# 4847                                 False                           False
# 4848                                 False                           False
#
#       WATER CUT  MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS
# 0         False                                              False
# 1         False                                              False
# 2         False                                              False
# 3         False                                              False
# 4         False                                              False
# ...         ...                                                ...
# 4844      False                                              False
# 4845      False                                              False
# 4846      False                                              False
# 4847      False                                              False
# 4848      False                                              False
#
# [4849 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4849 entries, 0 to 4848
# Data columns (total 8 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   BEST CALIPER,AVERAGE DIAMETER                      4849 non-null   float64
#  1   IMAGE DERIVED PHOTOELECTRIC FACTOR                 4849 non-null   float64
#  2   TOTAL POROSITY                                     4849 non-null   float64
#  3   RESISTIVITY OF WATER FILLED FORMATION              4849 non-null   float64
#  4   RELATIVE PERMEABILITY TO HYDROCARBON               4849 non-null   float64
#  5   RELATIVE PERMEABILITY TO WATER                     4849 non-null   float64
#  6   WATER CUT                                          4849 non-null   float64
#  7   MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS  4849 non-null   float64
# dtypes: float64(8)
# memory usage: 303.2 KB

# %%
df.isnull().sum()
# Out:
# BEST CALIPER,AVERAGE DIAMETER                        0
# IMAGE DERIVED PHOTOELECTRIC FACTOR                   0
# TOTAL POROSITY                                       0
# RESISTIVITY OF WATER FILLED FORMATION                0
# RELATIVE PERMEABILITY TO HYDROCARBON                 0
# RELATIVE PERMEABILITY TO WATER                       0
# WATER CUT                                            0
# MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS    0
# dtype: int64

# %%
x=['BEST CALIPER,AVERAGE DIAMETER',                        
'IMAGE DERIVED PHOTOELECTRIC FACTOR',                   
'TOTAL POROSITY',                         
'RESISTIVITY OF WATER FILLED FORMATION',                
'RELATIVE PERMEABILITY TO HYDROCARBON',                 
'RELATIVE PERMEABILITY TO WATER',                       
'WATER CUT',                                           
'MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS']
type(x)
# Out:
# list

# %%
c=0
for i in x:
#     print(i)
    for j in range(0,len(df[i])):
        if df[i][j]==-999.25:
            c+=1
print(c)
# Out:
# 79

# %%
df=df.replace(-999.25,np.NaN)
df.head()
# Out:
#    BEST CALIPER,AVERAGE DIAMETER  IMAGE DERIVED PHOTOELECTRIC FACTOR  \
# 0                        10.6431                             18.4555
# 1                        10.7011                             18.8648
# 2                        10.7012                             19.3160
# 3                        10.6773                             19.6845
# 4                        10.6162                             19.4390
#
#    TOTAL POROSITY  RESISTIVITY OF WATER FILLED FORMATION  \
# 0          0.1300                                 3.8568
# 1          0.1111                                 4.9163
# 2          0.1015                                 5.7882
# 3          0.0927                                 6.8120
# 4          0.1053                                 5.4189
#
#    RELATIVE PERMEABILITY TO HYDROCARBON  RELATIVE PERMEABILITY TO WATER  \
# 0                                   0.0                             1.0
# 1                                   0.0                             1.0
# 2                                   0.0                             1.0
# 3                                   0.0                             1.0
# 4                                   0.0                             1.0
#
#    WATER CUT  MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS
# 0        1.0                                             2.7292
# 1        1.0                                             2.7379
# 2        1.0                                             2.7397
# 3        1.0                                             2.7413
# 4        1.0                                             2.7459

# %%
df=df.dropna()
df.shape
# Out:
# (4770, 8)

# %%
df.mean()
# Out:
# BEST CALIPER,AVERAGE DIAMETER                        8.582265
# IMAGE DERIVED PHOTOELECTRIC FACTOR                   4.065263
# TOTAL POROSITY                                       0.146853
# RESISTIVITY OF WATER FILLED FORMATION                4.051761
# RELATIVE PERMEABILITY TO HYDROCARBON                 0.162358
# RELATIVE PERMEABILITY TO WATER                       0.762512
# WATER CUT                                            0.803867
# MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS    2.705721
# dtype: float64

# %%
df.describe()
# Out:
#        BEST CALIPER,AVERAGE DIAMETER  IMAGE DERIVED PHOTOELECTRIC FACTOR  \
# count                    4770.000000                         4770.000000
# mean                        8.582265                            4.065263
# std                         0.307876                            1.465728
# min                         8.377000                            1.491600
# 25%                         8.506000                            2.886725
# 50%                         8.536500                            4.328150
# 75%                         8.579600                            5.053400
# max                        15.250000                           19.684500
#
#        TOTAL POROSITY  RESISTIVITY OF WATER FILLED FORMATION  \
# count     4770.000000                            4770.000000
# mean         0.146853                               4.051761
# std          0.078821                               3.733882
# min          0.016400                               0.245500
# 25%          0.084525                               1.730275
# 50%          0.123650                               3.118500
# 75%          0.210575                               5.462725
# max          0.500000                             107.283100
#
#        RELATIVE PERMEABILITY TO HYDROCARBON  RELATIVE PERMEABILITY TO WATER  \
# count                           4770.000000                     4770.000000
# mean                               0.162358                        0.762512
# std                                0.320118                        0.414325
# min                                0.000000                        0.000000
# 25%                                0.000000                        0.729425
# 50%                                0.000000                        1.000000
# 75%                                0.000600                        1.000000
# max                                0.998700                        1.000000
#
#          WATER CUT  MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS
# count  4770.000000                                        4770.000000
# mean      0.803867                                           2.705721
# std       0.385308                                           0.035755
# min       0.000000                                           2.642700
# 25%       1.000000                                           2.683200
# 50%       1.000000                                           2.704000
# 75%       1.000000                                           2.720900
# max       1.000000                                           2.975300

# %%
Y=df["TOTAL POROSITY"]
Y.head()
# Out:
# 0    0.1300
# 1    0.1111
# 2    0.1015
# 3    0.0927
# 4    0.1053
# Name: TOTAL POROSITY, dtype: float64

# %%
X=df.drop("TOTAL POROSITY",axis=1)
X.head()
# Out:
#    BEST CALIPER,AVERAGE DIAMETER  IMAGE DERIVED PHOTOELECTRIC FACTOR  \
# 0                        10.6431                             18.4555
# 1                        10.7011                             18.8648
# 2                        10.7012                             19.3160
# 3                        10.6773                             19.6845
# 4                        10.6162                             19.4390
#
#    RESISTIVITY OF WATER FILLED FORMATION  \
# 0                                 3.8568
# 1                                 4.9163
# 2                                 5.7882
# 3                                 6.8120
# 4                                 5.4189
#
#    RELATIVE PERMEABILITY TO HYDROCARBON  RELATIVE PERMEABILITY TO WATER  \
# 0                                   0.0                             1.0
# 1                                   0.0                             1.0
# 2                                   0.0                             1.0
# 3                                   0.0                             1.0
# 4                                   0.0                             1.0
#
#    WATER CUT  MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS
# 0        1.0                                             2.7292
# 1        1.0                                             2.7379
# 2        1.0                                             2.7397
# 3        1.0                                             2.7413
# 4        1.0                                             2.7459

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=0)

# %%
X.value_counts()
# Out:
# BEST CALIPER,AVERAGE DIAMETER  IMAGE DERIVED PHOTOELECTRIC FACTOR  RESISTIVITY OF WATER FILLED FORMATION  RELATIVE PERMEABILITY TO HYDROCARBON  RELATIVE PERMEABILITY TO WATER  WATER CUT  MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS
# 8.3770                         2.3086                              0.7328                                 0.6608                                0.0007                          0.0296     2.6835                                               1
# 8.5629                         4.8905                              7.2678                                 0.0000                                1.0000                          1.0000     2.7136                                               1
#                                3.8064                              3.1193                                 0.0000                                1.0000                          1.0000     2.6991                                               1
#                                3.4933                              4.9808                                 0.0000                                1.0000                          1.0000     2.6429                                               1
# 8.5627                         4.8310                              2.1108                                 0.0000                                1.0000                          1.0000     2.6953                                               1
#                                                                                                                                                                                                                                                ..
# 8.5169                         5.0017                              3.1776                                 0.0000                                1.0000                          1.0000     2.7178                                               1
#                                4.0114                              3.6001                                 0.0000                                1.0000                          1.0000     2.7521                                               1
#                                3.9801                              2.5132                                 0.0000                                1.0000                          1.0000     2.7274                                               1
# 8.5168                         5.1307                              3.1936                                 0.0000                                1.0000                          1.0000     2.7209                                               1
# 15.2500                        2.7588                              0.2633                                 0.8940                                0.0000                          0.0000     2.7662                                               1
# Length: 4770, dtype: int64

# %%
Y.value_counts()
# Out:
# 0.5000    17
# 0.1013    12
# 0.0912    10
# 0.0615    10
# 0.0913    10
#           ..
# 0.1636     1
# 0.1891     1
# 0.1917     1
# 0.1037     1
# 0.0516     1
# Name: TOTAL POROSITY, Length: 2063, dtype: int64

# %%
X_train.shape
# Out:
# (3339, 7)

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
model.fit(X_train,Y_train)
random_pred= model.predict(X_test)

# %%
print(random_pred)
# Out:
# [0.111059 0.080165 0.247374 ... 0.06315  0.234202 0.263241]

# %%
model.score(X_test, Y_test)
# Out:
# 0.8919899131085531

# %%
model.score(X_train,Y_train)
# Out:
# 0.987317764753444

# %%
from sklearn.metrics import r2_score
r2= r2_score(Y_test,random_pred)
r2
# Out:
# 0.8919899131085531

# %%
from sklearn.metrics import mean_squared_error
randomforest_rmse=mean_squared_error(Y_test,random_pred,squared=False)
randomforest_rmse
# Out:
# 0.025686699896000063

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()

# %%
model1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model1.score(X_train,Y_train)
# Out:
# 0.7259802241300822

# %%
model1.score(X_test,Y_test)
# Out:
# 0.6639910973090399

# %%
lr_pred= model1.predict(X_test)
r2_lr= r2_score(Y_test,lr_pred)
r2_lr
# Out:
# 0.6639910973090399

# %%
lr_rmse=mean_squared_error(Y_test,lr_pred,squared=False)
lr_rmse
# Out:
# 0.045305564522006035

# %%
from sklearn import svm
model2=svm.SVR()
model2.fit(X_train,Y_train)
# Out:
# SVR()

# %%
svm_pred= model2.predict(X_test)
svm_r2= r2_score(Y_test,svm_pred)
svm_r2
# Out:
# 0.3292595855493311

# %%
model2.score(X_train,Y_train)
# Out:
# 0.3543254949851322

# %%
model2.score(X_test,Y_test)
# Out:
# 0.3292595855493311

# %%
svm_rmse=mean_squared_error(Y_test,svm_pred,squared=False)
svm_rmse
# Out:
# 0.06401082011858197

# %%
from sklearn import tree
model5=tree.DecisionTreeRegressor()
model5.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
model5.score(X_test,Y_test)
# Out:
# 0.7607546241401327

# %%
model5.score(X_train,Y_train)
# Out:
# 1.0

# %%
DT_pred= model5.predict(X_test)
r2_DT= r2_score(Y_test,DT_pred)
r2_DT
# Out:
# 0.7607546241401327

# %%
DT_rmse=mean_squared_error(Y_test,DT_pred,squared=False)
DT_rmse
# Out:
# 0.03822943946657761

# %%
import tensorflow as tf
import numpy as np


# define the model architecture
model6 = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# compile the model
model6.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='mse',
              metrics=['mae'])

# train the model
model6.fit(X_train,Y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 84/84 [==============================] - 4s 16ms/step - loss: 0.2828 - mae: 0.2391 - val_loss: 0.0071 - val_mae: 0.0479
# Epoch 2/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0130 - mae: 0.0548 - val_loss: 0.0023 - val_mae: 0.0286
# Epoch 3/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0018 - mae: 0.0274 - val_loss: 0.0023 - val_mae: 0.0280
# Epoch 4/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0018 - mae: 0.0268 - val_loss: 0.0019 - val_mae: 0.0258
# Epoch 5/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0017 - mae: 0.0255 - val_loss: 0.0019 - val_mae: 0.0307
# Epoch 6/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0019 - mae: 0.0272 - val_loss: 0.0023 - val_mae: 0.0277
# Epoch 7/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0018 - mae: 0.0274 - val_loss: 0.0021 - val_mae: 0.0350
# Epoch 8/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0018 - mae: 0.0269 - val_loss: 0.0019 - val_mae: 0.0248
# Epoch 9/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0019 - mae: 0.0279 - val_loss: 0.0018 - val_mae: 0.0252
# Epoch 10/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0018 - mae: 0.0270 - val_loss: 0.0023 - val_mae: 0.0391
# Epoch 11/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0023 - mae: 0.0343 - val_loss: 0.0020 - val_mae: 0.0249
# Epoch 12/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0040 - mae: 0.0391 - val_loss: 0.0029 - val_mae: 0.0464
# Epoch 13/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0049 - mae: 0.0450 - val_loss: 0.0022 - val_mae: 0.0290
# Epoch 14/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0029 - mae: 0.0352 - val_loss: 0.0019 - val_mae: 0.0246
# Epoch 15/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0019 - mae: 0.0293 - val_loss: 0.0021 - val_mae: 0.0246
# Epoch 16/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0017 - mae: 0.0261 - val_loss: 0.0018 - val_mae: 0.0287
# Epoch 17/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0017 - mae: 0.0259 - val_loss: 0.0020 - val_mae: 0.0357
# Epoch 18/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0017 - mae: 0.0266 - val_loss: 0.0018 - val_mae: 0.0303
# Epoch 19/50
# 84/84 [==============================] - 1s 8ms/step - loss: 0.0017 - mae: 0.0255 - val_loss: 0.0018 - val_mae: 0.0309
# Epoch 20/50
# 84/84 [==============================] - 0s 6ms/step - loss: 0.0018 - mae: 0.0273 - val_loss: 0.0023 - val_mae: 0.0276
# Epoch 21/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0017 - mae: 0.0261 - val_loss: 0.0020 - val_mae: 0.0335
# Epoch 22/50
# 84/84 [==============================] - 0s 6ms/step - loss: 0.0016 - mae: 0.0255 - val_loss: 0.0019 - val_mae: 0.0237
# Epoch 23/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0017 - mae: 0.0259 - val_loss: 0.0017 - val_mae: 0.0277
# Epoch 24/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0018 - mae: 0.0280 - val_loss: 0.0021 - val_mae: 0.0363
# Epoch 25/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0018 - mae: 0.0273 - val_loss: 0.0017 - val_mae: 0.0280
# Epoch 26/50
# 84/84 [==============================] - 0s 6ms/step - loss: 0.0017 - mae: 0.0261 - val_loss: 0.0018 - val_mae: 0.0252
# Epoch 27/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0019 - mae: 0.0291 - val_loss: 0.0017 - val_mae: 0.0264
# Epoch 28/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0017 - mae: 0.0257 - val_loss: 0.0017 - val_mae: 0.0267
# Epoch 29/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0017 - mae: 0.0267 - val_loss: 0.0017 - val_mae: 0.0248
# Epoch 30/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0016 - mae: 0.0258 - val_loss: 0.0020 - val_mae: 0.0251
# Epoch 31/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0018 - mae: 0.0276 - val_loss: 0.0020 - val_mae: 0.0343
# Epoch 32/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0019 - mae: 0.0294 - val_loss: 0.0017 - val_mae: 0.0242
# Epoch 33/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0017 - mae: 0.0277 - val_loss: 0.0018 - val_mae: 0.0244
# Epoch 34/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0017 - mae: 0.0270 - val_loss: 0.0017 - val_mae: 0.0242
# Epoch 35/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0017 - mae: 0.0267 - val_loss: 0.0019 - val_mae: 0.0246
# Epoch 36/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0016 - mae: 0.0261 - val_loss: 0.0017 - val_mae: 0.0272
# Epoch 37/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0016 - mae: 0.0261 - val_loss: 0.0018 - val_mae: 0.0240
# Epoch 38/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0018 - mae: 0.0274 - val_loss: 0.0017 - val_mae: 0.0238
# Epoch 39/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0017 - mae: 0.0269 - val_loss: 0.0018 - val_mae: 0.0320
# Epoch 40/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0019 - mae: 0.0293 - val_loss: 0.0017 - val_mae: 0.0244
# Epoch 41/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0016 - mae: 0.0261 - val_loss: 0.0018 - val_mae: 0.0238
# Epoch 42/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0016 - mae: 0.0254 - val_loss: 0.0021 - val_mae: 0.0377
# Epoch 43/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0018 - mae: 0.0279 - val_loss: 0.0017 - val_mae: 0.0250
# Epoch 44/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0017 - mae: 0.0262 - val_loss: 0.0017 - val_mae: 0.0252
# Epoch 45/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0019 - mae: 0.0287 - val_loss: 0.0017 - val_mae: 0.0272
# Epoch 46/50
# 84/84 [==============================] - 1s 7ms/step - loss: 0.0020 - mae: 0.0299 - val_loss: 0.0018 - val_mae: 0.0289
# Epoch 47/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0018 - mae: 0.0275 - val_loss: 0.0016 - val_mae: 0.0252
# Epoch 48/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0017 - mae: 0.0276 - val_loss: 0.0018 - val_mae: 0.0236
# Epoch 49/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0016 - mae: 0.0261 - val_loss: 0.0019 - val_mae: 0.0330
# Epoch 50/50
# 84/84 [==============================] - 1s 6ms/step - loss: 0.0016 - mae: 0.0259 - val_loss: 0.0020 - val_mae: 0.0359

# %%
# Predict on new data
y_pred = model.predict(X_test)

# %%
r2_ANN= r2_score(Y_test,y_pred)
r2_ANN
# Out:
# 0.8919899131085531

# %%
sns.displot(x='TOTAL POROSITY',data=df,kde=True)
# show the plot
plt.show()

# %%
all_cols = list(df.columns)
print(all_cols)
# Out:
# ['BEST CALIPER,AVERAGE DIAMETER', 'IMAGE DERIVED PHOTOELECTRIC FACTOR', 'TOTAL POROSITY', 'RESISTIVITY OF WATER FILLED FORMATION', 'RELATIVE PERMEABILITY TO HYDROCARBON', 'RELATIVE PERMEABILITY TO WATER', 'WATER CUT', 'MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS']

# %%
len(all_cols)
# Out:
# 8

# %%
histdf = df.hist(bins=100,figsize=(15,10))
plt.show()

# %%
plt.figure(figsize = (15, 15))
for i in enumerate(all_cols):
    plt.subplot(3, 3,i[0]+1)
    sns.boxplot(i[1], data = df)
    plt.xticks(rotation = 45)
plt.show()

# %%
depth_train= np.linspace(2700,3495,len(df))
df['Depth']= depth_train

# %%
df.head()
# Out:
#    BEST CALIPER,AVERAGE DIAMETER  IMAGE DERIVED PHOTOELECTRIC FACTOR  \
# 0                        10.6431                             18.4555
# 1                        10.7011                             18.8648
# 2                        10.7012                             19.3160
# 3                        10.6773                             19.6845
# 4                        10.6162                             19.4390
#
#    TOTAL POROSITY  RESISTIVITY OF WATER FILLED FORMATION  \
# 0          0.1300                                 3.8568
# 1          0.1111                                 4.9163
# 2          0.1015                                 5.7882
# 3          0.0927                                 6.8120
# 4          0.1053                                 5.4189
#
#    RELATIVE PERMEABILITY TO HYDROCARBON  RELATIVE PERMEABILITY TO WATER  \
# 0                                   0.0                             1.0
# 1                                   0.0                             1.0
# 2                                   0.0                             1.0
# 3                                   0.0                             1.0
# 4                                   0.0                             1.0
#
#    WATER CUT  MATRIX BULK DENSITY FROM ELEMENTAL CONCENTRATIONS        Depth
# 0        1.0                                             2.7292  2700.000000
# 1        1.0                                             2.7379  2700.166702
# 2        1.0                                             2.7397  2700.333403
# 3        1.0                                             2.7413  2700.500105
# 4        1.0                                             2.7459  2700.666806

# %%
df.plot(subplots=True,figsize=(10,30))
plt.show()

# %%
random_predict= model.predict(X_test)

# %%
random_predict
# Out:
# array([0.111059, 0.080165, 0.247374, ..., 0.06315 , 0.234202, 0.263241])

# %%
Y_test
# Out:
# 538     0.1021
# 668     0.0769
# 4343    0.2554
# 3684    0.2581
# 4508    0.0775
#          ...
# 4523    0.0995
# 4811    0.1065
# 257     0.0637
# 3609    0.2297
# 3931    0.2650
# Name: TOTAL POROSITY, Length: 1431, dtype: float64

# %%
random_predict.shape
# Out:
# (1431,)

# %%
preds= np.array(random_pred)
reals= np.array(Y_test)

# %%
r2= r2_score(Y_test,random_pred)
r2
# Out:
# 0.8919899131085531

# %%
# Plot results:
plt.figure(figsize=(15,5))
i = 0
#plt.subplot(1,2,i+1)
plt.plot(preds, reals, '.', label = 'r^2 = %.3f' % ((r2_score(reals, preds))))
plt.plot([reals.min(),reals.max()],[reals.min(),reals.max()], 'r', label = '1:1 line')
plt.title('#1 Porosity: y_true vs. y_ estimate for Random Forest'); plt.xlabel('Estimate'); plt.ylabel('True')
plt.legend()
plt.show()

# %%
preds= np.array(lr_pred)

# Plot results:
plt.figure(figsize=(15,5))
i = 0
#plt.subplot(1,2,i+1)
plt.plot(preds, reals, '.', label = 'r^2 = %.3f' % ((r2_score(reals, preds))))
plt.plot([reals.min(),reals.max()],[reals.min(),reals.max()], 'r', label = '1:1 line')
plt.title('#1 Porosity: y_true vs. y_ estimate for Linear Regression'); plt.xlabel('Estimate'); plt.ylabel('True')
plt.legend()
plt.show()

# %%
preds= np.array(svm_pred)

# Plot results:
plt.figure(figsize=(15,5))
i = 0
#plt.subplot(1,2,i+1)
plt.plot(preds, reals, '.', label = 'r^2 = %.3f' % ((r2_score(reals, preds))))
plt.plot([reals.min(),reals.max()],[reals.min(),reals.max()], 'r', label = '1:1 line')
plt.title('#1 Porosity: y_true vs. y_ estimate for SVM Regression'); plt.xlabel('Estimate Porosity'); plt.ylabel('True Porosity')
plt.legend()
plt.show()

# %%
model.feature_importances_
# Out:
# array([0.06412904, 0.03532999, 0.67896663, 0.02132614, 0.00437405,
#        0.00367263, 0.19220153])

# %%
corr= df.corr()

# %%
sns.heatmap(corr,annot=True)
plt.show()

# %%
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.06413
# Feature: 1, Score: 0.03533
# Feature: 2, Score: 0.67897
# Feature: 3, Score: 0.02133
# Feature: 4, Score: 0.00437
# Feature: 5, Score: 0.00367
# Feature: 6, Score: 0.19220

# %%
random_predict
# Out:
# array([0.111059, 0.080165, 0.247374, ..., 0.06315 , 0.234202, 0.263241])

# %%
print(importance)
# Out:
# [0.06412904 0.03532999 0.67896663 0.02132614 0.00437405 0.00367263
#  0.19220153]
